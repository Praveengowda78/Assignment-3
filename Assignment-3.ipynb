# %%
def calculator():
  operation= input('''
Please type in the math operation you would like to complete:
+ for addition
- for subtraction
* for multiplication
/ for division
''')


  num1=int(input("Enter the first number: "))
  num2=int(input("Enter the second number; "))

  if operation == '+':
    print('{} + {} = '.format(num1, num2))
    print(num1 + num2)
  elif operation == '-' :
    print('{} - {} = '.format(num1, num2))
    print(num1 - num2)
  elif operation == '*' :
    print('{} * {} = '.format(num1, num2))
    print(num1 * num2)
  elif operation == '/' :
    print('{} / {} = '.format(num1, num2))
    print(num1 / num2)
  else:
    print('You have not typed a valid operator.')
calculator()
# Out:
# Please type in the math operation you would like to complete:
# + for addition
# - for subtraction
# * for multiplication
# / for division
# *
# Enter the first number: 345
# Enter the second number; 566
# 345 * 566 =
# 195270

# %%
myfile=open("file.py","r+")
print(myfile.read())
myfile.write("developing a game\n")
# Out:
# developing a gamedeveloping a gamedeveloping a gamedeveloping a game
# 18

# %%
with open("file.py",'w+') as p:
  p.write("hey")
  p.write("\nIam praveen")
  p.seek(0)
  lines=p.read()
  print(lines)
# Out:
# hey
# Iam praveen

# %%
with open("file.py",'r+') as p:
  p.write("welcome\n")

# %%
with open("file.py",'a+') as p:
  p.write("bangalore")
  p.seek(0)
  lines=p.readlines()
  print(lines)
# Out:
# ['welcome\n', 'praveenbangalore']
